# %% [markdown]
# <a id="0"></a><br>
# # Проект: Обучение с учителем: качество модели

# %% [markdown]
# <a id="1"></a>
# ## Описание проекта

# %% [markdown]
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.<br><br>
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе. <br><br>
# Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# <a id="2"></a>
# ## Цель проекта

# %% [markdown]
# 1. Нужно промаркировать уровень финансовой активности постоянных покупателей. В компании принято выделять два уровня активности: «снизилась», если клиент стал покупать меньше товаров, и «прежний уровень».
# 1. Нужно собрать данные по клиентам по следующим группам:
# * Признаки, которые описывают коммуникацию сотрудников компании с клиентом.
# * Признаки, которые описывают продуктовое поведение покупателя. Например, какие товары покупает и как часто.
# * Признаки, которые описывают покупательское поведение клиента. Например, сколько тратил в магазине.
# * Признаки, которые описывают поведение покупателя на сайте. Например, как много страниц просматривает и сколько времени проводит на сайте.
#
# 1. Нужно построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца.
# 1. В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца.
# 1. Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.

# %% [markdown]
# <a id="3"></a>
# ## Исходные данные

# %% [markdown]
# Данные для работы находятся в нескольких таблицах.
#
# `market_file.csv`
# * `id` — номер покупателя в корпоративной базе данных.
# * `Покупательская активность` — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# * `Тип сервиса` — уровень сервиса, например «премиум» и «стандарт».
# * `Разрешить сообщать` — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# * `Маркет_актив_6_мес` — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# * `Маркет_актив_тек_мес` — количество маркетинговых коммуникаций в текущем месяце.
# * `Длительность` — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# * `Акционные_покупки` — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# * `Популярная_категория` — самая популярная категория товаров у покупателя за последние 6 месяцев.
# * `Средний_просмотр_категорий_за_визит` — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# * `Неоплаченные_продукты_штук_квартал` — общее число неоплаченных товаров в корзине за последние 3 месяца.
# * `Ошибка_сервиса` — число сбоев, которые коснулись покупателя во время посещения сайта.
# * `Страниц_за_визит` — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.

# %% [markdown]
# `market_money.csv`
# * `id` — номер покупателя в корпоративной базе данных.
# * `Период` — название периода, во время которого зафиксирована выручка. Например, 'текущий_месяц' или 'предыдущий_месяц'.
# * `Выручка` — сумма выручки за период.

# %% [markdown]
# `market_time.csv`
# * `id` — номер покупателя в корпоративной базе данных.
# * `Период` — название периода, во время которого зафиксировано общее время.
# * `минут` — значение времени, проведённого на сайте, в минутах.

# %% [markdown]
# `money.csv`
# * `id` — номер покупателя в корпоративной базе данных.
# * `Прибыль` — значение прибыли.

# %% [markdown]
# <a id="3.1"></a>
# ### Данный проект разделим на несколько частей.

# %% [markdown]
# Решать задачу нужно в два этапа:
# 1. Разработать модель, которая предскажет вероятность снижения покупательской активности.
# 1. Выделить сегмент покупателей, проанализировать его и предложить, как увеличить его покупательскую активность. Используем данные моделирования, данные о прибыли покупателей и исходные данные (если понадобятся). По желанию мы можем проанализировать больше одного сегмента.
#
# Ниже несколько примеров сегментов:
#
# * Группа клиентов с максимальной долей покупок по акции и высокой вероятностью снижения покупательской активности.
# * Группа клиентов, которые покупают только технику, то есть товары с длинным жизненным циклом.
# * Группа клиентов, которые покупают товары из категории «Товары для себя» (новая категория, которую можно выделить на основе текущих) или «Товары для детей».
# * Группа клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью.

# %% [markdown]
# [Часть 1. Описание проекта](#1)
# [Часть 2. Цель проекта](#2)
# [Часть 3. Описание исходных данных](#3)
# [Часть 4. Загрузка данных и изучение общей информации](#4)
# &nbsp;&nbsp;&nbsp;4.1. [Импорты модулей и общие функции](#5)
# &nbsp;&nbsp;&nbsp;4.2. [Анализ файла `market_file`](#6)
# &nbsp;&nbsp;&nbsp;4.3. [Анализ файла `market_money`](#7)
# &nbsp;&nbsp;&nbsp;4.4. [Анализ файла `market_time`](#8)
# &nbsp;&nbsp;&nbsp;4.5. [Анализ файла `money`](#9)
# &nbsp;&nbsp;&nbsp;4.6. [Гистограммы и ящики с усами](#10)
# [Часть 5. Предобработка данных](#11)
# &nbsp;&nbsp;&nbsp;5.1. [Пропущенные значения](#12)
# &nbsp;&nbsp;&nbsp;5.2. [Дубликаты](#13)
# &nbsp;&nbsp;&nbsp;5.3. [Аномалии](#14)
# [Часть 6. Исследовательский анализ данных](#15)
# &nbsp;&nbsp;&nbsp;6.1. [Данные `market_file`](#16)
# &nbsp;&nbsp;&nbsp;6.2. [Данные `market_money`](#17)
# &nbsp;&nbsp;&nbsp;6.3. [Данные `market_time`](#18)
# &nbsp;&nbsp;&nbsp;6.4. [Данные `money`](#19)
# &nbsp;&nbsp;&nbsp;6.5. [Отбор клиентов с покупательской активностью не менее трёх месяцев](#20)
# [Часть 7. Объединение таблиц](#21)
# [Часть 8. Корреляционный анализ данных](#22)
# &nbsp;&nbsp;&nbsp;8.1. [Взаимосвязь между признаками](#23)
# &nbsp;&nbsp;&nbsp;8.2. [Диаграммы рассеяния](#24)
# [Часть 9. Использование пайплайнов](#25)
# &nbsp;&nbsp;&nbsp;9.1. [Выбор метрики](#26)
# [Часть 10. Анализ важности признаков](#27)
# [Часть 11. Сегментация покупателей](#28)
# &nbsp;&nbsp;&nbsp;11.1. [Формирование датафрейма с учетом предсказаний](#29)
# &nbsp;&nbsp;&nbsp;11.2. [Отбор группы покупателей](#30)
# [Часть 12. Общие выводы](#31)

# %% [markdown]
# <a id="4"></a>
# ## Загрузка данных и изучение общей информации

# %% [markdown]
# <a id="5"></a>
# ### Импорты модулей и общие функции

# %%
import warnings
warnings.filterwarnings('ignore')

# !pip install ydata_profiling -q
# !pip install phik -q
# !pip install shap -q
# !pip install -U scikit-learn -q

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
import shap

# %%
def view_and_get_data(path, sep=None, decimal=","):
    """
    Открывает файл, выводит первые 10 строк,
    основную информцию о дата фрейме и возвращает датафрейм.
    Принимает разделить в csv файле и разделитель десятичных чисел(по умолчанию запятая).
    """
    try:
        # Пробуем открыть файл локально, если нет, то через сервер яндекса.
        data = pd.read_csv(path, sep=sep, decimal=decimal, engine='python')
    except Exception:
        print('Локальный файл не найден. Пробую открыть серверную версию файла.')
        data = pd.read_csv(f'https://заперт_делиться_фреймом{path}', sep=sep, decimal=decimal)
        
    display(data.head(10))
    data.info()
    return data


def hist_and_box_numeric(data):
    """
    Принимает датафрейм для построения гистрограм и боксплотов для
    числовых столбцев.
    """
    columns = data.select_dtypes(exclude=['object']).columns.to_list()
    fig, axes = plt.subplots(nrows=len(columns), ncols=2, figsize=(10, 20))
    
    for number in range(len(columns)):
        data[columns[number]].plot(
            ax=axes[number, 0], kind="hist", ylabel=columns[number], rot=0);
        axes[number, 0].set_title(f'Гистограмма {columns[number]}')
        axes[number, 0].set_ylabel('Количество')
        axes[number, 0].set_xlabel('Значения признака')
        data[columns[number]].plot(
            ax=axes[number, 1], kind="box", ylabel='Разброс показателя', rot=0);
        axes[number, 1].set_title(f'Ящик с усами {columns[number]}')
    fig.tight_layout()

    
def hist_and_box_obj(data):
    """
    Принимает датафрейм для построения гистрограм и боксплотов для
    категориальных столбцев.
    """
    columns = data.select_dtypes(include=['object']).columns

    if len(columns) > 1:
        columns = columns.to_list()
        fig, axes = plt.subplots(nrows=len(columns), ncols=1, figsize=(10, 20))
        for number in range(len(columns)):
            data[columns[number]].value_counts(normalize=True).plot(
                ax=axes[number], kind='bar', xlabel=columns[number], ylabel='Доля', rot=15);
            axes[number].set_title(f'Диаграмма {columns[number]}')
        fig.tight_layout()
    else:
        columns = columns.to_list()
        data[columns[0]].value_counts(normalize=True).plot(
            kind='bar', xlabel=columns[0], ylabel='Доля', rot=15, title=f'Диаграмма {columns[0]}');

# %% [markdown]
# <a id="6"></a>
# ### [Анализ файла `market_file`](#3.1)

# %%
market_file_data = view_and_get_data('/datasets/market_file.csv')
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
# 5  215353                 Снизилась   стандартт                 да
# 6  215354                 Снизилась   стандартт                 да
# 7  215355                 Снизилась   стандартт                нет
# 8  215356                 Снизилась   стандартт                 да
# 9  215357                 Снизилась   стандартт                 да
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# ...

# %% [markdown]
# В файле порядка 1300 строк и 13 столбцов. Название колонок на русском, так и оставим, три столбца переименуем под стиль snake case и все приведем к нижнему регистру. 4 колонок строковго типа, 2 колонки чисел с плавающей точкой, 7 колонок с целочисленным типом.

# %%
market_file_data.columns = map(str.lower, market_file_data.columns)
market_file_data = market_file_data.rename(columns={
    'покупательская активность': 'покупательская_активность',
    'тип сервиса': 'тип_сервиса',
    'разрешить сообщать': 'разрешить_сообщать'
})
market_file_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   покупательская_активность            1300 non-null   object
#  2   тип_сервиса                          1300 non-null   object
#  3   разрешить_сообщать                   1300 non-null   object
#  4   маркет_актив_6_мес                   1300 non-null   float64
#  5   маркет_актив_тек_мес                 1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   популярная_категория                 1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %% [markdown]
# <a id="7"></a>
# ### [Анализ файла `market_money`](#3.1)

# %%
market_money_data = view_and_get_data('/datasets/market_money.csv')
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6
# 5  215349     предыдущий_месяц   5216.0
# 6  215350  препредыдущий_месяц   4826.0
# 7  215350        текущий_месяц   5058.4
# 8  215350     предыдущий_месяц   5457.5
# 9  215351        текущий_месяц   6610.4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
market_money_data.columns = map(str.lower, market_money_data.columns)
market_money_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   период   3900 non-null   object
#  2   выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# Привели наименование колонок к нижнему регистру. Во фрейме порядка 3900 строк и 3 колонки. 1 колонка целочисленного типа, 1 строковая, 1 из чисел с плавающей точкой.

# %% [markdown]
# <a id="8"></a>
# ### [Анализ файла `market_time`](#3.1)

# %%
market_time_data = view_and_get_data('/datasets/market_time.csv')
# Out:
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13
# 5  215350  предыдцщий_месяц      8
# 6  215351     текущий_месяц     13
# 7  215351  предыдцщий_месяц     11
# 8  215352     текущий_месяц     11
# 9  215352  предыдцщий_месяц      8
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %% [markdown]
# Заметили ошибку в названии периода и сразу поправили.

# %%
market_time_data['Период'] = market_time_data['Период'].replace('предыдцщий_месяц', 'предыдущий_месяц')

# %%
market_time_data.columns = map(str.lower, market_time_data.columns)
market_time_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %% [markdown]
# Привели наименование колонок к нижнему регистру. Во фрейме порядка 2600 строк и 3 колонки. 2 колонки целочисленного типа, 1 строковая.

# %% [markdown]
# <a id="9"></a>
# ### [Анализ файла `money`](#3.1)

# %%
money_data = view_and_get_data('/datasets/money.csv')
# Out:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21
# 5  215353     3.95
# 6  215354     3.62
# 7  215355     5.26
# 8  215356     4.93
# 9  215357     4.66
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %%
money_data.columns = map(str.lower, money_data.columns)
money_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %% [markdown]
# Привели наименование колонок к нижнему регистру. Во фрейме порядка 1300 строк и 2 колонки. 1 колонка целочисленного типа, 1 чисел с плавающей точкой.

# %% [markdown]
# <a id="10"></a>
# ### [Гистограммы и ящики с усами](#3.1)

# %%
hist_and_box_numeric(market_file_data.drop(['id'], axis=1))

# %%
hist_and_box_obj(market_file_data.drop(['id'], axis=1))

# %% [markdown]
# Замечено совпадение типа сервиса, только в одном две "тт". испарвим это сразу.

# %%
market_file_data['тип_сервиса'] = market_file_data['тип_сервиса'].replace(
    {'стандартт': 'стандарт'}
)

# %% [markdown]
# По части файла маркета явных выборосов не видно, немного выбиваются акционные покупки, при которых скидка была более 0.9.

# %%
hist_and_box_numeric(market_money_data)

# %%
hist_and_box_obj(market_money_data.drop(['id'], axis=1))

# %% [markdown]
# В разделе выручки имеет один явный и очень большой выброс, либо слишком хорошую выручку, который будет необходимо удалить. Остальные данные в целом распределены нормально.

# %%
hist_and_box_numeric(market_time_data)

# %%
hist_and_box_obj(market_time_data.drop(['id'], axis=1))

# %% [markdown]
# Касательно времени проведенного на сайте проблем не видно.

# %%
hist_and_box_numeric(money_data)

# %% [markdown]
# С прибылью так же всё в порядке, явных выбросов нет.

# %% [markdown]
# **Вывод:** В целом распределение данных довольно равномерно и логично. Присутствует явный выброс касательно выручки, в остальном данные распределены в разумных пределах.

# %% [markdown]
# <a id="11"></a>
# ##  Предобработка данных

# %%
def short_describe(data):
    """Сокращенная версия метдоа describe для упроженного анализа признаков."""
    data = data.describe()
    display(data[data.index.isin(['std', '50%', 'min', 'max'])].T)

# %% [markdown]
# <a id="12"></a>
# ### [Пропущенные значения](#3.1)

# %% [markdown]
# По анализу файлов видно, что пропущенных значений по фреймах нет.

# %% [markdown]
# <a id="13"></a>
# ### [Дубликаты](#3.1)

# %% [markdown]
# Проверим явные дубликаты.

# %%
print('Количество явных дубликатов market_file:', market_file_data.duplicated().sum())
print('Количество явных дубликатов market_money:', market_money_data.duplicated().sum())
print('Количество явных дубликатов market_time:', market_time_data.duplicated().sum())
print('Количество явных дубликатов money:', money_data.duplicated().sum())
# Out:
# Количество явных дубликатов market_file: 0
# Количество явных дубликатов market_money: 0
# Количество явных дубликатов market_time: 0
# Количество явных дубликатов money: 0

# %% [markdown]
# Явных дубликатов во фреймах нет. Проверять на неявные дубликат фреймы кроме `market_file` смысла нет, поскольку в остальных только `id` и какая-нибудь категория.

# %%
market_file_data[market_file_data.duplicated(subset=[
    'id',
    'покупательская_активность',
    'длительность',
    'акционные_покупки',
    'популярная_категория'
])]
# Out:
# Empty DataFrame
# Columns: [id, покупательская_активность, тип_сервиса, разрешить_сообщать, маркет_актив_6_мес, маркет_актив_тек_мес, длительность, акционные_покупки, популярная_категория, средний_просмотр_категорий_за_визит, неоплаченные_продукты_штук_квартал, ошибка_сервиса, страниц_за_визит]
# Index: []

# %% [markdown]
# Скорее всего неявных дубликатов так же нет.

# %% [markdown]
# <a id="14"></a>
# ### [Аномалии](#3.1)

# %% [markdown]
# Проверим аномалии в данных, как минимум в одном датафрейме мы уже знаем, что есть.

# %%
short_describe(market_file_data.drop(['id'], axis=1))
# Out:
#                                             std    min     50%      max
# маркет_актив_6_мес                     1.014814    0.9    4.20     6.60
# маркет_актив_тек_мес                   0.696868    3.0    4.00     5.00
# длительность                         249.856289  110.0  606.00  1079.00
# акционные_покупки                      0.249843    0.0    0.24     0.99
# средний_просмотр_категорий_за_визит    1.355350    1.0    3.00     6.00
# неоплаченные_продукты_штук_квартал     1.971451    0.0    3.00    10.00
# ошибка_сервиса                         1.955298    0.0    4.00     9.00
# страниц_за_визит                       3.978126    1.0    8.00    20.00

# %% [markdown]
# В целом по дата фрейму маркета каких-то исключительно больших выбросов нет. `неоплаченные_продукты_штук_квартал` принимают значение в 10 единиц, при медианном значении в 3 единицы и отклонении в 2 единицы. Может быть, скорее всего кто-то передумал. Примерно такое же и со страницами за визит.

# %%
short_describe(market_money_data.drop(['id'], axis=1))
# Out:
#                  std  min     50%       max
# выручка  1777.704104  0.0  4957.5  106862.2

# %% [markdown]
# А вот с выручкой обстоят дела странно, при медианной в 5 тысяч, есть значение более 100 тысяч. Возможно это было исключительная попытка, но для наших условий стоило бы от такого избавиться.

# %%
market_money_data.query("выручка > 106862")
# Out:
#         id         период   выручка
# 98  215380  текущий_месяц  106862.2

# %%
market_money_data.query("id == 215380")
# Out:
#         id               период   выручка
# 96  215380  препредыдущий_месяц    5051.0
# 97  215380     предыдущий_месяц    6077.0
# 98  215380        текущий_месяц  106862.2

# %%
market_file_data.query("id == 215380")
# Out:
#         id покупательская_активность тип_сервиса разрешить_сообщать  \
# 32  215380                 Снизилась     премиум                нет
#
#     маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 32                 1.7                     4           637               0.94
#
#               популярная_категория  средний_просмотр_категорий_за_визит  \
# 32  Техника для красоты и здоровья                                    3
#
#     неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит
# 32                                   2               4                 7

# %% [markdown]
# В ходе небольшого анализа выдим, что данный покупатель только в текущем месяце принес нам такую огромную выручку. За 6 месяцев он в среднем был активен 1 раз в два месяца, но довольно высоки акционные покупки, вероятно покупки были осуществлены из-за акций. Уберем эту одну запись с выбивающейся выручкой, чтобы она не вносила шум в данные.

# %%
market_money_data = market_money_data.query("выручка < 106000")

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Отлично. Еще вариант − можно было бы поменять выброс на значение выручки по предыдущему периоду для этого же пользователя.
# </div>

# %%
short_describe(market_money_data.drop(['id'], axis=1))
# Out:
#                std  min     50%     max
# выручка  706.99988  0.0  4957.0  7799.4

# %% [markdown]
# Теперь это уже ближе к реальности.

# %%
short_describe(market_time_data.drop(['id'], axis=1))
# Out:
#             std  min   50%   max
# минут  4.080198  4.0  13.0  23.0

# %% [markdown]
# Время адекватное, выбросов нет.

# %%
short_describe(money_data.drop(['id'], axis=1))
# Out:
#               std   min    50%   max
# прибыль  1.013722  0.86  4.045  7.43

# %% [markdown]
# **Вывод:** В датафреймах больших выбросов нет. Был обнаружен один значительный выбров для выручки, который мы удалили.

# %% [markdown]
# <a id="15"></a>
# ## Исследовательский анализ данных

# %%
def research_numeric_data(data, value):
    """Выводим описание столбца числового типа, гистограмму с этим столбцом."""
    print('Описание данных:')
    display(data[value].describe().T)
    print()
    print('Уникальные значения(10 наиболее частых):')
    display(data[value].value_counts(ascending=False).head(10))
    print()
    fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(15, 5))

    data[value].plot(
        ax=axes[0], kind="hist", rot=0);
    axes[0].set_title(f"Гистограмма {value}")
    axes[0].set_ylabel('Количество')
    axes[0].set_xlabel(f'Значения признака {value}')
    data[value].plot(
        ax=axes[1], kind="box", xlabel=value, rot=0);
    axes[1].set_title(f'Ящик с усами {value}')
    fig.tight_layout()

    
def research_object_data(data, value):
    """Выводим описание столбца категориального типа, график с этим столбцом."""
    print('Уникальные значения:')
    display(data[value].value_counts(ascending=False))
    print()
    print(f'Линейчатый график для показателя: {value}')
    data[value].value_counts().plot(
        kind="bar",
        xlabel=value,
        ylabel='Количество',
        rot=45);

def research_numeric_data_with_target(data, value, target):
    """
    Распределение числового признака в зависимости от целевого.
    Наложенные диаграммы и два боксплота.
    """
    fig, axes = plt.subplots(nrows=1, ncols=3,figsize=(15, 5))
    
    unique_target = data[target].unique()
    
    data[data[target] == unique_target[0]][value].plot(
        ax=axes[0], kind="hist", rot=0, color="r", label=unique_target[0], alpha=0.5)
    data[data[target] == unique_target[1]][value].plot(
        ax=axes[0], kind="hist", rot=0, color="g", label=unique_target[1], alpha=0.5)
    axes[0].set_title('Гистограммы с целевым признаком')
    axes[0].set_ylabel('Количество')
    axes[0].legend()
    axes[0].set_xlabel(f'Значения признака {value}')
    
    data[data[target] == unique_target[0]][value].plot(
        ax=axes[1], kind="box", xlabel=value, rot=0);
    axes[1].set_title(f'Боксплот с целевым признаком {unique_target[0]}')
    
    data[data[target] == unique_target[1]][value].plot(
        ax=axes[2], kind="box", xlabel=value, rot=0);
    axes[2].set_title(f'Боксплот с целевым признаком {unique_target[1]}')
    fig.tight_layout()

def research_object_data_with_target(data, value, target):
    """
    Распределение категориального признака в зависимости от целевого.
    Две диаграммы.
    """
    fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(15, 5))
    
    unique_target = data[target].unique()
    
    data[data[target] == unique_target[0]][value].value_counts().plot(
        ax=axes[0],
        kind="bar",
        xlabel=value,
        ylabel='Количество',
        rot=45, color="r");
    axes[0].set_title(f'График для показателя: {value} c признаком {unique_target[0]}')

    data[data[target] == unique_target[1]][value].value_counts().plot(
        ax=axes[1],
        kind="bar",
        xlabel=value,
        ylabel='Количество',
        rot=45, color="g");
    axes[1].set_title(f'График для показателя: {value} c признаком {unique_target[1]}')
    fig.tight_layout()

# %% [markdown]
# <a id="16"></a>
# ### [Данные `market_file`](#3.1)

# %%
market_file_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   покупательская_активность            1300 non-null   object
#  2   тип_сервиса                          1300 non-null   object
#  3   разрешить_сообщать                   1300 non-null   object
#  4   маркет_актив_6_мес                   1300 non-null   float64
#  5   маркет_актив_тек_мес                 1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   популярная_категория                 1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %% [markdown]
# Для данного фрейма рассмотрим 12 признаков.

# %% [markdown]
# #### [покупательская_активность](#16)

# %%
research_object_data(market_file_data, 'покупательская_активность')
# Out:
# Уникальные значения:
# Прежний уровень    802
# Снизилась          498
# Name: покупательская_активность, dtype: int64
# Линейчатый график для показателя: покупательская_активность

# %% [markdown]
# #### [тип_сервиса](#16)

# %%
research_object_data(market_file_data, 'тип_сервиса')
# Out:
# Уникальные значения:
# стандарт    924
# премиум     376
# Name: тип_сервиса, dtype: int64
# Линейчатый график для показателя: тип_сервиса

# %%
research_object_data_with_target(market_file_data, 'тип_сервиса', 'покупательская_активность')

# %% [markdown]
# #### [разрешить_сообщать](#16)

# %%
research_object_data(market_file_data, 'разрешить_сообщать')
# Out:
# Уникальные значения:
# да     962
# нет    338
# Name: разрешить_сообщать, dtype: int64
# Линейчатый график для показателя: разрешить_сообщать

# %%
research_object_data_with_target(market_file_data, 'разрешить_сообщать', 'покупательская_активность')

# %% [markdown]
# #### [маркет_актив_6_мес](#16)

# %%
research_numeric_data(market_file_data, 'маркет_актив_6_мес')
# Out:
# Описание данных:
# count    1300.000000
# mean        4.253769
# std         1.014814
# min         0.900000
# 25%         3.700000
# 50%         4.200000
# 75%         4.900000
# max         6.600000
# Name: маркет_актив_6_мес, dtype: float64
# Уникальные значения(10 наиболее частых):
# 4.1    94
# 3.9    83
# 4.4    82
# 4.0    71
# 5.5    68
# 4.3    66
# 4.9    60
# 3.5    50
# 4.6    49
# 3.3    47
# Name: маркет_актив_6_мес, dtype: int64

# %%
research_numeric_data_with_target(market_file_data, 'маркет_актив_6_мес', 'покупательская_активность')

# %% [markdown]
# #### [маркет_актив_тек_мес](#16)

# %%
research_numeric_data(market_file_data, 'маркет_актив_тек_мес')
# Out:
# Описание данных:
# count    1300.000000
# mean        4.011538
# std         0.696868
# min         3.000000
# 25%         4.000000
# 50%         4.000000
# 75%         4.000000
# max         5.000000
# Name: маркет_актив_тек_мес, dtype: float64
# Уникальные значения(10 наиболее частых):
# 4    669
# 5    323
# 3    308
# Name: маркет_актив_тек_мес, dtype: int64

# %%
research_numeric_data_with_target(market_file_data, 'маркет_актив_тек_мес', 'покупательская_активность')

# %% [markdown]
# #### [длительность](#16)

# %%
research_numeric_data(market_file_data, 'длительность')
# Out:
# Описание данных:
# count    1300.000000
# mean      601.898462
# std       249.856289
# min       110.000000
# 25%       405.500000
# 50%       606.000000
# 75%       806.000000
# max      1079.000000
# Name: длительность, dtype: float64
# Уникальные значения(10 наиболее частых):
# 627    7
# 600    7
# 449    7
# 503    6
# 511    6
# 744    6
# 788    6
# 324    6
# 475    6
# 666    6
# Name: длительность, dtype: int64

# %%
research_numeric_data_with_target(market_file_data, 'длительность', 'покупательская_активность')

# %% [markdown]
# #### [акционные_покупки](#16)

# %%
research_numeric_data(market_file_data, 'акционные_покупки')
# Out:
# Описание данных:
# count    1300.000000
# mean        0.319808
# std         0.249843
# min         0.000000
# 25%         0.170000
# 50%         0.240000
# 75%         0.300000
# max         0.990000
# Name: акционные_покупки, dtype: float64
# Уникальные значения(10 наиболее частых):
# 0.24    93
# 0.30    85
# 0.28    83
# 0.17    79
# 0.25    72
# 0.14    69
# 0.21    64
# 0.13    64
# 0.16    62
# 0.23    60
# Name: акционные_покупки, dtype: int64

# %%
research_numeric_data_with_target(market_file_data, 'акционные_покупки', 'покупательская_активность')

# %% [markdown]
# Наблюдаем два пика, претендент на перевод в категориальный признак.

# %% [markdown]
# <div class="alert alert-info">
# Можно сказать, что есть две группы пользователей, которые купив вещь с небольшой скидкой, больше ничего не покупают, и те, кто ждет максимальной скидки. Причем примерное количество таких людей со снижением активности одинаково. Я бы подумал, что это перекупщики. Они ждут скидку на определенный товар, покупают его и на достаточно долгое время теряют интерес. Либо за счет акций/бонусов и прочего ждут максимальной акции на товары. При этом в этой группе может так же быть и человек, который хочет купить конкретный товар и ждет скидку на него, но по виду таких людей меньше, поскольку категории товаров в зависимости от целевого признака примерно одинаковы. Нельзя явно выделить группу покупателей, который ждут скидку на именно бытовую технику и после их актиность снижается. Мне кажется, что по предоставленным данным группа просто ждет снижения цены. При этом времени группа со снижением активности на сайте тратит меньше, что указываем на более конкретный поиск товаров.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Снова привет. Спасибо за заметное оформление твоих комментариев.
#
# По дополнению в контексте целевого признака − отлично.
#
# По выводу - ну не думаю, что перекупщики, хотя можно оставить как гипотезу. Возможно, просто была некоторая акция, внешняя реклама, набежали покупатели, накупили конкретно интересное им, а дальше в остальных предложениях маркета не заинтересовались. Нужно бы их как-то подхватить, предложить что-то интересное, рассказать, что сервис полезный и им можно пользоваться постоянно.
# </div>

# %% [markdown]
# #### [популярная_категория](#16)

# %%
research_object_data(market_file_data, 'популярная_категория')
# Out:
# Уникальные значения:
# Товары для детей                        330
# Домашний текстиль                       251
# Косметика и аксесуары                   223
# Техника для красоты и здоровья          184
# Мелкая бытовая техника и электроника    174
# Кухонная посуда                         138
# Name: популярная_категория, dtype: int64
# Линейчатый график для показателя: популярная_категория

# %%
research_object_data_with_target(market_file_data, 'популярная_категория', 'покупательская_активность')

# %% [markdown]
# #### [средний_просмотр_категорий_за_визит](#16)

# %%
research_numeric_data(market_file_data, 'средний_просмотр_категорий_за_визит')
# Out:
# Описание данных:
# count    1300.00000
# mean        3.27000
# std         1.35535
# min         1.00000
# 25%         2.00000
# 50%         3.00000
# 75%         4.00000
# max         6.00000
# Name: средний_просмотр_категорий_за_визит, dtype: float64
# Уникальные значения(10 наиболее частых):
# 3    356
# 2    312
# 4    263
# 5    177
# 1    106
# 6     86
# Name: средний_просмотр_категорий_за_визит, dtype: int64

# %%
research_numeric_data_with_target(market_file_data, 'средний_просмотр_категорий_за_визит', 'покупательская_активность')

# %% [markdown]
# #### [неоплаченные_продукты_штук_квартал](#16)

# %%
research_numeric_data(market_file_data, 'неоплаченные_продукты_штук_квартал')
# Out:
# Описание данных:
# count    1300.000000
# mean        2.840000
# std         1.971451
# min         0.000000
# 25%         1.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: неоплаченные_продукты_штук_квартал, dtype: float64
# Уникальные значения(10 наиболее частых):
# 1    261
# 2    261
# 3    218
# 4    197
# 5    135
# 0    116
# 6     44
# 7     34
# 8     20
# 9     10
# Name: неоплаченные_продукты_штук_квартал, dtype: int64

# %%
research_numeric_data_with_target(market_file_data, 'неоплаченные_продукты_штук_квартал', 'покупательская_активность')

# %% [markdown]
# #### [ошибка_сервиса](#16)

# %%
research_numeric_data(market_file_data, 'ошибка_сервиса')
# Out:
# Описание данных:
# count    1300.000000
# mean        4.185385
# std         1.955298
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         6.000000
# max         9.000000
# Name: ошибка_сервиса, dtype: float64
# Уникальные значения(10 наиболее частых):
# 4    257
# 3    226
# 5    208
# 2    189
# 6    156
# 7     92
# 1     74
# 8     66
# 0     17
# 9     15
# Name: ошибка_сервиса, dtype: int64

# %%
research_numeric_data_with_target(market_file_data, 'ошибка_сервиса', 'покупательская_активность')

# %% [markdown]
# #### [<font style="color: red">страниц_за_визит</font>](#16)

# %%
research_numeric_data(market_file_data, 'страниц_за_визит')
# Out:
# Описание данных:
# count    1300.000000
# mean        8.176923
# std         3.978126
# min         1.000000
# 25%         5.000000
# 50%         8.000000
# 75%        11.000000
# max        20.000000
# Name: страниц_за_визит, dtype: float64
# Уникальные значения(10 наиболее частых):
# 6     127
# 5     115
# 4     112
# 8     109
# 9     108
# 10    104
# 7     102
# 11     92
# 3      76
# 12     73
# Name: страниц_за_визит, dtype: int64

# %%
research_numeric_data_with_target(market_file_data, 'страниц_за_визит', 'покупательская_активность')

# %% [markdown]
# **Вывод:** распрееление данных нормальное, выбросов данных нет. Несколько признаков претенденты перевода с количественных в категориальные: `маркет_актив_тек_мес`, `акционные_покупки` и `неоплаченные_продукты_штук_квартал`.

# %% [markdown]
# <div class="alert alert-info">
# На графиках с учетом целевого признака, можно заметить, что категория пользователей у которых снизился уровень активности, меньше просматривают страницы за визит, чаще покупали товары по привлекательным акциям, больше товаров оставляли с корзине неоплаченными, сильно на это влияют акционные покупки, количество просмотренных категорий. Получается, что покупатель ждал скидку или акцию на какой-то конкретный товар и после покупки такового был менее заинтересовал в дальнейших покупках.

# %% [markdown]
# <div class="alert alert-info">
# О, как интересно. Создам новые функции для этого и визуализирую это в разделах для каждого признака, чтобы не оставлять ниже кучу графиков без разделов. Получился очень интересный разбор зависимостей признаков, где мы уже видим некоторые особенности поведения двух групп. Спасибо!

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 Да, у аналитиков (и в соседнем курсе Практикума, и в жизни) вообще правило − в любой непонятной ситуации смотреть признаки в разрезе целевого. Да и вообще это основа любых экспериментов (меняем что-то одно в условиях, смотрим, как изменяется результат).
# </div>

# %% [markdown]
# <a id="17"></a>
# ### [Данные `market_money`](#3.1)

# %% [markdown]
# #### [выручка](#17)

# %%
research_numeric_data(market_money_data, 'выручка')
# Out:
# Описание данных:
# count    3899.00000
# mean     4999.57743
# std       706.99988
# min         0.00000
# 25%      4590.10000
# 50%      4957.00000
# 75%      5363.00000
# max      7799.40000
# Name: выручка, dtype: float64
# Уникальные значения(10 наиболее частых):
# 4729.0    8
# 5051.0    7
# 4952.0    7
# 0.0       6
# 4795.0    6
# 5028.0    6
# 4648.0    6
# 4974.0    6
# 4798.0    5
# 5204.0    5
# Name: выручка, dtype: int64

# %% [markdown]
# Изначально был заметен якобы выброс с нулевой выручкой. Полагаю, что это товар, на который была акция со 100% скидкой. Давайте проверим.

# %%
display(market_money_data.query("выручка == 0"))

id_money_zero = market_money_data.query("выручка == 0")['id']
market_file_data.query("id in @id_money_zero")
# Out:
#         id               период  выручка
# 0   215348  препредыдущий_месяц      0.0
# 2   215348     предыдущий_месяц      0.0
# 28  215357  препредыдущий_месяц      0.0
# 29  215357     предыдущий_месяц      0.0
# 34  215359     предыдущий_месяц      0.0
# 35  215359  препредыдущий_месяц      0.0
#         id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0   215348                 Снизилась     премиум                 да
# 9   215357                 Снизилась    стандарт                 да
# 11  215359                 Снизилась    стандарт                 да
#
#     маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                  3.4                     5           121                0.0
# 9                  3.9                     5           154                0.0
# 11                 4.6                     5           110                0.0
#
#               популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %%
money_data.query("id in @id_money_zero")
# Out:
#         id  прибыль
# 0   215348     0.98
# 9   215357     4.66
# 11  215359     5.08

# %% [markdown]
# Теория не подтвердилась. Это не клиенты, которые купили товар по слишком привлекательной акции, а клиенты, которые заходили на сайт, но ничего не купили. Возможно, они не нашли то что искали или ждут скудку на определенные товары. Если посмотреть на принесенную прибыль этими клиентами, то она есть. Скорее всего клиент покупал не через сайт, а по телефону например, что вполне может быть, но искал товары или подбирал их на сайте. "Хочу вот такое, но только красное" - и продажа осуществлялась через склад. Сложная ситуация для анализа и учета в модели, но запомним.

# %% [markdown]
# #### [<font style="color: red">период</font>](#17)

# %%
research_object_data(market_money_data, 'период')
# Out:
# Уникальные значения:
# препредыдущий_месяц    1300
# предыдущий_месяц       1300
# текущий_месяц          1299
# Name: период, dtype: int64
# Линейчатый график для показателя: период

# %% [markdown]
# **Вывод:** в этом фрейме данные так же распределены нормально, явных выбросов нет. Исключать пользователей, которые не приносят выручку - не логично, но запомним, если в дальнейшем нам потребуется как-то иначе оценить покупателей.

# %%
market_money_data = market_money_data[market_money_data['выручка'] != 0]

# %%
market_money_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3893 entries, 1 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3893 non-null   int64
#  1   период   3893 non-null   object
#  2   выручка  3893 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 121.7+ KB

# %% [markdown]
# <a id="18"></a>
# ### [Данные `market_time`](#3.1)

# %% [markdown]
# #### [период](#18)

# %%
research_object_data(market_time_data, 'период')
# Out:
# Уникальные значения:
# текущий_месяц       1300
# предыдущий_месяц    1300
# Name: период, dtype: int64
# Линейчатый график для показателя: период

# %% [markdown]
# #### [минут](#18)

# %%
research_numeric_data(market_time_data, 'минут')
# Out:
# Описание данных:
# count    2600.000000
# mean       13.336154
# std         4.080198
# min         4.000000
# 25%        10.000000
# 50%        13.000000
# 75%        16.000000
# max        23.000000
# Name: минут, dtype: float64
# Уникальные значения(10 наиболее частых):
# 14    256
# 12    237
# 11    221
# 13    206
# 10    204
# 9     186
# 15    174
# 17    163
# 16    162
# 18    145
# Name: минут, dtype: int64

# %% [markdown]
# **Вывод:** данные распределены нормально, выбросов или аномалий нет.

# %% [markdown]
# <a id="19"></a>
# ### [Данные `money`](#3.1)

# %%
research_numeric_data(money_data, 'прибыль')
# Out:
# Описание данных:
# count    1300.000000
# mean        3.996631
# std         1.013722
# min         0.860000
# 25%         3.300000
# 50%         4.045000
# 75%         4.670000
# max         7.430000
# Name: прибыль, dtype: float64
# Уникальные значения(10 наиболее частых):
# 3.89    11
# 4.28     9
# 5.10     9
# 4.18     9
# 2.93     8
# 4.33     8
# 3.45     8
# 4.31     8
# 4.61     8
# 4.50     8
# Name: прибыль, dtype: int64

# %% [markdown]
# **Вывод:** с этим фреймом так же всё нормально и логично.

# %% [markdown]
# <a id="20"></a>
# ### [<font style="color: red">Отбор клиентов с покупательской активностью не менее трёх месяцев</font>](#3.1)

# %%
market_money_for_concat = pd.pivot_table(
    market_money_data,
    values='выручка',
    columns='период',
    index='id',
).reset_index()
market_money_for_concat.head()
# Out:
# период      id  предыдущий_месяц  препредыдущий_месяц  текущий_месяц
# 0       215348               NaN                  NaN         3293.1
# 1       215349            5216.0               4472.0         4971.6
# 2       215350            5457.5               4826.0         5058.4
# 3       215351            6158.0               4793.0         6610.4
# 4       215352            5807.5               4594.0         5872.5

# %% [markdown]
# Проверим наличие None.

# %% [markdown]
# market_money_for_concat.isna().sum()

# %% [markdown]
# market_money_for_concat = market_money_for_concat.fillna(0)
# market_money_for_concat.isna().sum()

# %% [markdown]
# market_money_for_concat = market_money_for_concat.query("предыдущий_месяц > 0 or препредыдущий_месяц > 0 or текущий_месяц > 0")
# market_money_for_concat.head()

# %% [markdown]
# ~~**Вывод:** если за последние три месяца у пользователей не было активности, то мы их исключили из фрейма, а так же заполнили None нулем на случай, если такое еще будет втречаться.~~

# %%
market_money_for_concat = market_money_for_concat.dropna()

# %%
market_money_for_concat.isna().sum()
# Out:
# период
# id                     0
# предыдущий_месяц       0
# препредыдущий_месяц    0
# текущий_месяц          0
# dtype: int64

# %%
market_money_for_concat.head()
# Out:
# период      id  предыдущий_месяц  препредыдущий_месяц  текущий_месяц
# 1       215349            5216.0               4472.0         4971.6
# 2       215350            5457.5               4826.0         5058.4
# 3       215351            6158.0               4793.0         6610.4
# 4       215352            5807.5               4594.0         5872.5
# 5       215353            4738.5               5124.0         5388.5

# %%
market_money_for_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1296 entries, 1 to 1299
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1296 non-null   int64
#  1   предыдущий_месяц     1296 non-null   float64
#  2   препредыдущий_месяц  1296 non-null   float64
#  3   текущий_месяц        1296 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 50.6 KB

# %% [markdown]
# **Вывод:** если пользователь не приносил прибыли в один из трех последних месяцев, то он был исключен и датафрейма. В итоге в датафрейме остались только те пользователи, которые что-либо покупали каждый месяц с оценкой их активности. Касательно

# %% [markdown]
# <a id="21"></a>
# ## <font style="color: red">Объединение таблиц </font>

# %% [markdown]
# Выделяю процесс объединения таблиц в отдельных раздел, поскольку после объединения так же есть требование сделать отдельный столбец для каждого периода.

# %%
market_money_for_concat = market_money_for_concat.rename(columns={
    'предыдущий_месяц': 'предыдущий_месяц_выручка',
    'препредыдущий_месяц': 'препредыдущий_месяц_выручка',
    'текущий_месяц': 'текущий_месяц_выручка',
})
market_money_for_concat.head()
# Out:
# период      id  предыдущий_месяц_выручка  препредыдущий_месяц_выручка  \
# 1       215349                    5216.0                       4472.0
# 2       215350                    5457.5                       4826.0
# 3       215351                    6158.0                       4793.0
# 4       215352                    5807.5                       4594.0
# 5       215353                    4738.5                       5124.0
#
# период  текущий_месяц_выручка
# 1                      4971.6
# 2                      5058.4
# 3                      6610.4
# 4                      5872.5
# 5                      5388.5

# %%
# В данном случае мы какбы переворачиваем таблицу, уводим строки с периодом в столбцы.
market_time_for_concat = pd.pivot_table(
    market_time_data,
    values='минут',
    columns='период',
    index='id',
).reset_index()
market_time_for_concat = market_time_for_concat.rename(columns={
    'предыдущий_месяц': 'предыдущий_месяц_минут',
    'текущий_месяц': 'текущий_месяц_минут',
})
market_time_for_concat.head()
# Out:
# период      id  предыдущий_месяц_минут  текущий_месяц_минут
# 0       215348                      13                   14
# 1       215349                      12                   10
# 2       215350                       8                   13
# 3       215351                      11                   13
# 4       215352                       8                   11

# %%
market_all_data = pd.merge(
    market_file_data,
    market_money_for_concat,
    how='right',
    on='id'
)
market_all_data = pd.merge(
    market_all_data,
    market_time_for_concat,
    how='left',
    on='id'
)
market_all_data.head()
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215350                 Снизилась    стандарт                нет
# 2  215351                 Снизилась    стандарт                 да
# 3  215352                 Снизилась    стандарт                нет
# 4  215353                 Снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
# 3                 5.1                     3          1064               0.94
# 4                 3.3                     4           762               0.26
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# ...

# %% [markdown]
# По логике раздела нам нужно получить отдельные столбцы для каждого периода. Оценивая, что мы занимаемся машинным обучением, то логично разделить данные по месяцам с подписью выручки и минут, так мы поймем к чему этот период относится, да и машинка сможет обучаться на этих данных.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# По объединению все верно.
#
# ***
#
# Выше нужно отобрать только активных клиентов.
#
# В исследовательском анализе нужно отдельно рассмотреть распределения признаков для подвыборок по целевому признаку (отдельно смотрим снизивших активность и клиентов с прежней активностью). В выводе выводи портрет пользователя, который снизил активность, находим, какие признаки повлияли на это больше всего.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Поправлено.
#
# Можно сказать, что есть две группы пользователей, которые купив вещь с небольшой скидкой, больше ничего не покупают, и те, кто ждет максимальной скидки. Причем примерное количество таких людей со снижением активности одинаково. Я бы подумал, что это перекупщики. Они ждут скидку на определенный товар, покупают его и на достаточно долгое время теряют интерес. Либо за счет акций/бонусов и прочего ждут максимальной акции на товары. При этом в этой группе может так же быть и человек, который хочет купить конкретный товар и ждет скидку на него, но по виду таких людей меньше, поскольку категории товаров в зависимости от целевого признака примерно одинаковы. Нельзя явно выделить группу покупателей, который ждут скидку на именно бытовую технику и после их актиность снижается. Мне кажется, что по предоставленным данным группа просто ждет снижения цены. При этом времени группа со снижением активности на сайте тратит меньше, что указываем на более конкретный поиск товаров.

# %% [markdown]
# <a id="22"></a>
# ## Корреляционный анализ

# %%
def scatter_plot(data, x, y, objects):
    """Строит диаграммы рассеяния по переданным признакам в зависимости от списка категориальных."""
    row = 0
    column = 0
    fig, axes = plt.subplots(nrows=(len(objects) % 3), ncols=3, figsize=(20, 15))
    for obj in objects:
        sns.scatterplot(data=data, x=x, y=y, hue=obj, palette="husl", ax=axes[row, column])
        column += 1
        if column == 3:
            column = 0
            row += 1
    plt.show()

# %% [markdown]
# <a id="23"></a>
# ### [<font style="color: red">Взаимосвязь между признаками</font>](#3.1)

# %%
sns.set(rc={"figure.figsize": (20, 20)})
sns.heatmap(market_all_data.drop(['id'], axis=1).corr(method='spearman'), annot=True, fmt='.2f');

# %% [markdown]
#
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# `sns.set(rc={"figure.figsize": (20, 20)})` - в этой строке ты выставляешь глобальные параметры, которые будут применены ко всему проекту. Это хорошее решение, когда явное указание размера графика почему-то не срабатывает.
#
# Однако мы должны сначала объявить глобально, что все графики отображаем в размере 20х20, а потом строить график. Если делать наоборот, то параметр не успеет примениться.
#
# ```
# sns.set(rc={"figure.figsize": (20, 20)})
# sns.heatmap(market_all_data.drop(['id'], axis=1).corr(method='spearman'), annot=True, fmt='.2f');
# ```
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Спасибо, поправил!

# %% [markdown]
# В целом признаков с сильной линейной зависимостью нет, слабая связь у `предыдущий_месяц_минут` и `страниц_за_визит`, порядка 0.45. А вот мультиколлинерность нам может дать 0.88 между `предыдущий_месяц_выручка` с `текущий_месяц_выручка`. В некотором смысле связь есть и странно, что она получилась такой сильной. По опыту предыдущий работ  от такого следует избавляться, поскольку модель линейной регрессии спасибо за это нам не скажет, но удаляя такой признак - мы лишаем модель довольно важного критерия. Нам же нужно предсказать покупательскую активность, давайте выпилим данные о покупаках за текущий месяц или предыдущий потому, что они коллерируют между собой? Неть! Если пользователь купил что-то в текущем месяца, можно ожидать спада в следующем, но не обязательно. Точно так же как и если он купил в предыдущем, то может быть спад в текущем, но новый рост в следуюшем. Я следую логике, что если пользователь что-то купил в текущем месяце, то он может захотеть сделать перерыв в месяц и купить уже в следующем. Не правило, не обязательно, что так будет, но может быть категория людей, которые так поступают. оставлю всё как есть, а дальше уже посмотрим.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Как бы это не звучало, «оставлю всё как есть, а дальше уже посмотрим» - хороший подход. Если мультиколлинеарность приведет к неустойчивости модели или к ее неработоспособности, мы это точно увидим, тогда вернемся и попробуем другие варианты с признаками.
#
# В целом, с корреляцией до 0.9 можно все признаки оставлять.
#
# Абсолютно верное рассуждение о том, что хотя признаки и коррелируют так сильно, причинно-следственной связи между ними нет. Факт покупок в предыдущем месяце не гарантирует, что покупатель будет покупать и в следующем.
# </div>

# %% [markdown]
# <a id="24"></a>
# ### [Диаграммы рассеяния](#3.1)

# %%
axes = pd.plotting.scatter_matrix(market_all_data.drop(['id'], axis=1), figsize=(15, 15));
for ax in axes.flatten():
    ax.xaxis.label.set_rotation(90)
    ax.yaxis.label.set_rotation(0)
    ax.yaxis.label.set_ha('right')

# %% [markdown]
# Лучше видно по матрице, но в целом и в матрице рассеяния размером с марку можно что-то разглядеть... Заметная линейная зависимость между выручкой текущего и предыдущего месяца. Акционные покупки вполне делятся не несколько групп. Маркет_актив_тек_месяца может уйти в категориальный признак. У прочих признаков значения распределены довольно равномерно.

# %% [markdown]
#
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# По акционным здесь или выше обязательно нужно прокомментировать шире, почему там два пика в гистограмме. Кто все эти люди, которые покупают товары только по акции. В любом случае, нужно и здесь, и ниже в анализе сегмента, их не упускать из вида.
#
# Обрати внимание, когда будешь рассматривать признаки в контексте таргета, как ведут себя пользователи, которые почти все покупают по акции.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Спасибо, теперь стало лучше понятно и зачем нужно разделение по признакам, так действительно можно делать шире вывод о группе таких пользователей. Как итог - меньше времени проводят на сайте, покупают разные категории товаров без превалирования конкретной категории товаров.

# %% [markdown]
# <a id="25"></a>
# ## Использование пайплайнов

# %% [markdown]
# Зададим константы перед пайплайнами.

# %%
RANDOM_STATE = 4241
TEST_SIZE = 0.25

# %%
market_all_data[market_all_data['текущий_месяц_выручка'].isna()]
# Out:
# Empty DataFrame
# Columns: [id, покупательская_активность, тип_сервиса, разрешить_сообщать, маркет_актив_6_мес, маркет_актив_тек_мес, длительность, акционные_покупки, популярная_категория, средний_просмотр_категорий_за_визит, неоплаченные_продукты_штук_квартал, ошибка_сервиса, страниц_за_визит, предыдущий_месяц_выручка, препредыдущий_месяц_выручка, текущий_месяц_выручка, предыдущий_месяц_минут, текущий_месяц_минут]
# Index: []

# %%
# Вот как можно было дойти до того, что нужно вот это поменять на число?! Спустя сотню ссылок гугла я таки нашел такое.
market_all_data['покупательская_активность'] = market_all_data[
    'покупательская_активность'].apply(lambda x: 0 if x == 'Прежний уровень' else 1)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 В линейных моделях (предыдущем проекте) вроде бы тоже нужно было делать таргетэнкодинг для логистической регресии.
#
# Вообще, соглашусь, надо поднять этот вопрос и добавить в теорию, о таргетэнкодинг многие спотыкаются.
# </div>

# %% [markdown]
# Разделим данные на обучающую и тестовую выборки. Удалим из исходного

# %%
X_train, X_test, y_train, y_test = train_test_split(
    market_all_data.drop(['покупательская_активность', 'id'], axis=1),
    market_all_data['покупательская_активность'],
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE,
    stratify = market_all_data['покупательская_активность'])
X_train.shape, X_test.shape
# Out:
# ((972, 16), (324, 16))

# %% [markdown]
# Cоздаём списки с названиями признаков.

# %%
ohe_columns = ['разрешить_сообщать', 'популярная_категория']
ord_columns = ['тип_сервиса']
num_columns = market_all_data.drop(
    ['покупательская_активность', 'id', 'разрешить_сообщать'],
    axis=1
).select_dtypes(exclude=['object']).columns.to_list()

# %% [markdown]
# Создаём пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование. У нас нет пропусков, как мы убедились на этапе ранее, но это не значит, что позже их тоже не будет, поэтому лучше заранее предусмотреть такой вариант, чтобы потом не переписывать.

# %%
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='error'))  # , sparse=False
    ]
    )
# drop='first', handle_unknown='ignore'

# %% [markdown]
# Создаём пайплайн для подготовки признаков из списка ord_columns: заполнение пропусков и Ordinal-кодирование.

# %%
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[ 
                    ['стандарт', 'премиум'],
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %% [markdown]
# Cоздаём общий пайплайн для подготовки данных.

# %%
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %% [markdown]
# Создаём итоговый пайплайн: подготовка данных и модель.

# %%
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %% [markdown]
# Далее создаем пайплайн для требуемых моделей.

# %%
param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 6),
        'models__max_features': range(2, 6),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier(metric='minkowski')],
        'models__n_neighbors': range(2, 6),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear',  # saga
            penalty='l1'
        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели SVC()
    {
        'models': [SVC(
            random_state=RANDOM_STATE,
            probability=True,
            #decision_function_shape='ovo'
       )],
        'models__C': [0.1, 1, 5, 10],
        'models__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],  # усталь перебирать их, пока искал ошибку, пусть так.
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'] 
    }
]

# %% [markdown]
# <a id="26"></a>
# ### [<font style="color: red">Выбор метрики</font>](#3.1)

# %% [markdown]
# Одной из целей проекта является маркировка финансовой активности клиентов. При этом нам нужно охватить всех клиентов без выделения интересов в плане снизилась активность или возросла. Поэтому использование precision или recall и максимизация одного из них не подойдёт. Можно предположить, что подойдёт accuracy, ведь нам важна точность предсказаний модели, но нет - она не учитывает соотношения ложных срабатываний модели. Если человек покупает много, а мы определяем его как того, кто покупал мало и начинаем заваливать предложениями, то получится не очень хорошо. Поэтому, по сути как в разделе теории, будем использовать метрику `roc_auc` - как компромисс между количеством положительно определенной активности клиентов и количеством неправильно положительно определенной активности клиентов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍 Согласен. НАм важно учитывать и полноту, и точность. Подойдут компленсные метрики, ROC_AUC в числе таких.
# </div>

# %% [markdown]
# С метрикой определились, теперь перейдем к опредлению наилучшей модели для нашей задачи.

# %%
# %%time
rs = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    scoring='roc_auc', 
    cv=5,
    n_jobs=-1
)
rs.fit(X_train, y_train)
# Out:
# CPU times: user 1.86 s, sys: 115 ms, total: 1.98 s
# Wall time: 1.99 s
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first'))]),
#                                                                                ['разрешить_сообщать',
# ...

# %%
print('Лучшая модель и её параметры:\n\n', rs.best_estimator_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first'))]),
#                                                   ['разрешить_сообщать',
#                                                    'популярная_категория']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
#                                                                    SimpleImputer(strategy='most_frequent')),...
# ...

# %% [markdown]
# rs.best_estimator_[0].transformers_[-1]

# %%
print('Метрика ROC-AUC для лучшей модели:\n', rs.best_score_)
# Out:
# Метрика ROC-AUC для лучшей модели:
#  0.904940396594942

# %% [markdown]
# y_test_pred = rs.predict(X_test)
# print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_pred)}')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2><s> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>На доработку🤔:</b>
#
# roc_auc нужно считать по вероятностям классов (сразу прошу прощения, если в теории было иначе и до сих пор не поправили).
#
# `probabilities = model.predict_proba(features)
# probabilities_one = probabilities[:, 1]
# print('Площадь ROC-кривой:', roc_auc_score(target, probabilities_one))`
#
# Самое подробное объяснение метрики, что я видел на русском языке, можно посмотреть здесь: https://alexanderdyakonov.wordpress.com/2017/07/28/auc-roc-площадь-под-кривой-ошибок/
#
# А внутри кросс-валидации мы просто указываем метрику ROC_AUC и там никаких вероятностей нам не нужно. Так как эта метрика имеет проблемы с дифференцированием, то там разработчики кросс-валидации хитро меняют ее на эквивалент Gini, так как Gini = 2 ×AUC_ROC – 1 (можно почитать по ссылке выше).
# </div>

# %% [markdown]
# <div class="alert alert-info">
# О, понял. Пробел в знаниях почему именно predict_proba, а не predict заполнен. В теории поправлено, та мпросто написано считаем так и куча непонятного текста, который забывается после прочтения. Это я про себя, так-то теория грамотна. Почитал статью по ссылке, отдельно лучше понял ROC_AUC и стало понятно почему так. Перепрочел теорию и да, там это тоже объясняется. Наверное, для моего уровня восприятия просто не хватает "почему не predict".

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# 👍 О! Крут, наконец-то поправили в теории)
#
# Да, это нормально, когда у нас все метрики считаются одинаково, можно упустить из вида, что эта − иначе.
#
# Кстати, про `Gini = 2 ×AUC_ROC – 1 ` - запомни этот момент наудачу. На собесах часто спрашивают про эту хитрость.
# </div>

# %%
probabilities = rs.predict_proba(X_test)[:, 1]
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, probabilities)}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.8943089430894309

# %% [markdown]
# **Вывод:** Лучшей моделью при использовании RandomizedSearchCV получилась LogisticRegression(C=4, penalty='l1', random_state=4241,solver='liblinear')). Модель показала хорошие рузультаты 0,91 на обучающей и ~~0,86~~ 0.89 на тестовой выборке.

# %% [markdown]
# <a id="27"></a>
# ## Анализ важности признаков

# %% [markdown]
# Проанализируем важность признаков и построим график важности.

# %%
# Вот этого в теории не было, куча гугла, проб и ошибок и помощь коллеги.
X_train_v = pipe_final.named_steps['preprocessor'].fit_transform(X_train)
explainer = shap.Explainer(rs.best_estimator_.named_steps['models'], X_train_v)
 
X_test_v = pipe_final.named_steps['preprocessor'].transform(X_test)
feature_names = pipe_final.named_steps['preprocessor'].get_feature_names_out()
X_test_v = pd.DataFrame(X_test_v, columns=feature_names)
 
shap_values = explainer(X_test_v)
 
display(shap.plots.bar(shap_values, max_display=30))
shap.plots.beeswarm(shap_values, max_display=30)
# Out:
# None

# %% [markdown]
# **Выводы о значимости признаков.**
#
# Наиболее важные для модели признаки:
# * количество страниц за визит;
# * средний просмотр категорий за визит;
# * определенные категории;
# * акционные покупки.
#
# Наименее важные признаки для модели:
# * выручки предыдущего и текущего месяца;
# * ошибки сервиса;
# * длительность пребывания и ошибки.
#
# При принятии решений для бизнеса следует руководствоваться:
# * чем больше пользователь совершает действий на сайте, просматривает категорий, тем меньше вероятность снижения активности пользователя;
# * если пользователя интересуют определенные товары, то при появлении акций на них снизится и вероятность дальнейшей активности пользователя;
# * чем больше пользователь добавляет товаров в корзину и не оплачивает их, тем больше вероятность снижения его активноности, что скорее всего обусловлено покупкой аналогичных товаров у конкурентов(возможно имеет смысл напоминание о забытых товарах в корзине);
# * акционные мероприятия так же соразмерно влияют на покупательскую активность
#
# Поскольку мы используем рандом, то при следующем запуске важность признаков может поменяться.

# %% [markdown]
# <a id="28"></a>
# ## Сегментация покупателей

# %% [markdown]
# <a id="29"></a>
# ### [Формирование датафрейма с учетом предсказаний](#3.1)

# %% [markdown]
# Используем результаты моделирования и данные о прибыльности покупателей.

# %%
market_all_data['вероятность_снижения'] = rs.predict_proba(market_all_data)[:, 1]
segment = pd.merge(money_data, market_all_data[['id', 'вероятность_снижения']], on='id', how='right')
segment.head()
# Out:
#        id  прибыль  вероятность_снижения
# 0  215349     4.16              0.916871
# 1  215350     3.13              0.538365
# 2  215351     4.87              0.793231
# 3  215352     4.21              0.981281
# 4  215353     3.95              0.656479

# %% [markdown]
# Построим диаграмму рассеяния, чтобы лучше увидеть распределения возможного снижения вероятности.

# %%
sns.scatterplot(data=segment, x="вероятность_снижения", y="прибыль");

# %% [markdown]
# Основные группы вероятностей находятся примерно у прибыли 4. Поэтому далее используем группу пользователей из предложенных: Группа клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью. По крайней мере мне именно эта группа вспомнилась, да и интересно будет проанализировать поведения такой группы покупателей.

# %% [markdown]
# <a id="30"></a>
# ### [<font style="color: red">Отбор группы покупателей</font>](#3.1)

# %% [markdown]
# Как ранее определились возьмём группу покупателей с прибылью выше 4, а в качестве показателя снижения покупательской активности пользователей возьмем 0.8. На диаграмме рассеяния выше именно на этом уровне более явно образуется группа вероятностей. То есть отбираем `id` исследуемой группы покупателей, объединяем это с исходными данными для анализа наиболее популярных категорий у данного сегмента покупателей.

# %%
segment_id = segment.query('прибыль > 4 & вероятность_снижения > 0.8')['id'].tolist()
segment_in_market_file = market_file_data.query('id in @segment_id')
segment_buyers = pd.merge(segment_in_market_file, market_money_data, on='id', how='left')
segment_buyers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 510 entries, 0 to 509
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   510 non-null    int64
#  1   покупательская_активность            510 non-null    object
#  2   тип_сервиса                          510 non-null    object
#  3   разрешить_сообщать                   510 non-null    object
#  4   маркет_актив_6_мес                   510 non-null    float64
#  5   маркет_актив_тек_мес                 510 non-null    int64
#  6   длительность                         510 non-null    int64
#  7   акционные_покупки                    510 non-null    float64
#  8   популярная_категория                 510 non-null    object
#  9   средний_просмотр_категорий_за_визит  510 non-null    int64
#  10  неоплаченные_продукты_штук_квартал   510 non-null    int64
# ...

# %% [markdown]
# sb_prepred = segment_buyers[
#     segment_buyers['период'] == 'препредыдущий_месяц'
#     ].groupby('популярная_категория')['выручка'].sum().sort_values(ascending=False)
# sb_prepred.plot(
#     kind='bar',
#     ylabel='выручка',
#     rot=15,
#     title='Выручка за препредыдущий_месяц по категориям',
#     figsize=(10, 10)
# );

# %% [markdown]
# sb_pred = segment_buyers[
#     segment_buyers['период'] == 'предыдущий_месяц'
#     ].groupby('популярная_категория')['выручка'].sum().sort_values(ascending=False)
# sb_pred.plot(
#     kind='bar',
#     ylabel='выручка',
#     rot=15,
#     title='Выручка за предыдущий_месяц по категориям',
#     figsize=(10, 10)
# );

# %% [markdown]
# sb_now = segment_buyers[
#     segment_buyers['период'] == 'текущий_месяц'
#     ].groupby('популярная_категория')['выручка'].sum().sort_values(ascending=False)
# sb_now.plot(
#     kind='bar',
#     ylabel='выручка',
#     rot=15,
#     title='Выручка за текущий_месяц по категориям',
#     figsize=(10, 10)
# );

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Удобнее посмотреть так: берем и вычисляем разницу в выручке между месяцами (группируем по пользователям для каждой категории). Смотрим, где просели.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Огось! Отличный подход. Действительно, так лучше будет заметна динамика и будет динамика, а не простое сравнение двух графиков. Спасибо!

# %%
sb_prepred = segment_buyers[
    segment_buyers['период'] == 'препредыдущий_месяц'
    ].groupby('популярная_категория')['выручка'].sum().sort_values(ascending=False)
sb_pred = segment_buyers[
    segment_buyers['период'] == 'предыдущий_месяц'
    ].groupby('популярная_категория')['выручка'].sum().sort_values(ascending=False)
sb_now = segment_buyers[
    segment_buyers['период'] == 'текущий_месяц'
    ].groupby('популярная_категория')['выручка'].sum().sort_values(ascending=False)

# %%
pred_prepred = sb_pred - sb_prepred
pred_prepred.plot(
    kind='bar',
    ylabel='выручка',
    rot=15,
    title='Разница выручки между предпредыдущим месяцем и предыдущим',
    figsize=(10, 10)
);

# %%
now_pred = sb_now - sb_pred
now_pred.plot(
    kind='bar',
    ylabel='выручка',
    rot=15,
    title='Разница выручки между текущим месяцем и предыдущим',
    figsize=(10, 10)
);

# %%
now_prepred = sb_now - sb_prepred
now_prepred.plot(
    kind='bar',
    ylabel='выручка',
    rot=15,
    title='Разница выручки между текущим месяцем и предпредыдущим',
    figsize=(10, 10)
);

# %% [markdown]
# ~~В течение выбранного периода распределение покупок по категориям примерно одинаковое, каких-то сильных перекосов между категорями нет. То есть каждая категория приносит примерно такой же доход от месяца к месяцу. Посмотрим как часто покупают товар указанных категорий. Будет ли там разница.~~

# %%
pred_prepred.plot(
    kind='bar',
    ylabel='выручка',
    rot=15,
    title='Разница выручки между предпредыдущим месяцем и предыдущим',
    figsize=(10, 10),
    alpha=0.5,
    color='r'
);
now_pred.plot(
    kind='bar',
    ylabel='выручка',
    rot=15,
    title='Разница выручки между текущим месяцем и предыдущим',
    figsize=(10, 10),
    alpha=0.5,
    color='g'
);
now_prepred.plot(
    kind='bar',
    ylabel='выручка',
    rot=15,
    title='Разница выручки между текущим месяцем и предпредыдущим',
    figsize=(10, 10),
    alpha=0.5,
    color='y'
);
plt.legend(['pred_prepred', 'now_pred', 'now_prepred'])

# %% [markdown]
# <div class="alert alert-info">
# Прибыль от категории "Техника для красоты и здоровья" снижается в текущем периоде. Она больше чем была в предыдущем, но не дотягивает до предпредыдущего уровня. В целом выручка растет, наиболее заметно это для категории "Косметика и аксесуары", затем для "Домашний текстиль".

# %%
segment_buyers['популярная_категория'].value_counts().plot(
    kind='bar',
    ylabel='количество покупок товаров данной категории',
    title='покупки товаров по категориям',
    rot=15,
    figsize=(10, 10)
);

# %% [markdown]
# Примерно такое же распределение. Получается, что выручка распределеяется примерно одинаково по количеству купленных товаров, то есть вариант утюга в стразах по цене квартиры не предусмотрено. Выясним далее была ли зависимость покупок от акций.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# У нас есть категория, прибыль по которой снижается между парой периодов.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# Спасибо за идею о наложении графиков, в данном проекте это действительно очень хорошо визуализирующий подход, как и в похожих работах. В плане сравнений и динамики это отлично подходит.

# %%
segment_buyers['акционные_покупки'].plot(
    kind='hist',
    ylabel='количество покупок товаров по акции',
    title='покупки товаров в зависимости от акции',
    rot=15,
    figsize=(10, 10)
);

# %% [markdown]
# Визуально покупателей можно разделить на две группы, как мы видели и ранее при анализе исходного датафрейма. Далее посмотрим, долю тех кто дал согласие на рассылку ежду тем, кто против рассылок.

# %%
segment_buyers['разрешить_сообщать'].value_counts(normalize=True).plot(
    kind='pie',
    ylabel=' ',
    title='Доля согласившихся на оповещения',
    rot=15,
    figsize=(7, 7),
    autopct="%.2f%%",
    colors=["g", "r"]
);

# %% [markdown]
# Практически 3/4 пользователей соглались получать рекламную рассылку, что говорит о желании приобретать разные товары, интерес к ним, интерес к возможным акциям на разные товары. Остается еще рассмотреть тип сервиса, чтобы так же понять, объем покупателей того и иного уровня.

# %%
segment_buyers['тип_сервиса'].value_counts(normalize=True).plot(
    kind='pie',
    ylabel=' ',
    title='Доля типа сервиса',
    rot=15,
    figsize=(7, 7),
    autopct="%.2f%%",
    colors=["g", "r"]
);

# %% [markdown]
# Тут же мы видим картину, что только у 30% пользователей премиум аккаунт.

# %% [markdown]
# **Вывод:** у выбранного сегмента пользователей в 30% случаев примерно имеется премиум сервис, 3/4 всех пользователей согласились получать рассылки, в целом пользователей можно разделить на две группы по части покупок по акциям, наиболее популярные товары для покупок и приносящих прибыль - товары для детей, косметика и аксессуары, а так же домашний текстиль.
#
# **Предложения:**
# * выслать категории без подписки предложения о таковой, что может повысить нашу выручку с этого, а покупателем позволит покупать товары более выгодно и получать информацию об акциях и скидках раньше других пользователей;
# * можно провести рекламную компанию на наиболее популярные категории в течение следующих нескольких месяцев, что может увеличить объем продаж, либо сосредоточиться на наименее популярных категоряих и рекламы товаров этой категории - ожидая, что это послужит напоминанием пользователем о покупках, которые они хотели сделать, но не сделали;
# * если реализовано отслеживание определенных категорий товаров, то отдельно для пользователей, которые интересовались определенными категорями высылать отдельную рекламную рассылку по таким товарам.

# %% [markdown]
# <div class="alert alert-info">
# Я не совсем понял, про что ты, но в целом решил провести доп анализ.

# %%
segment_buyers.groupby('популярная_категория')['акционные_покупки'].median().sort_values(
    ascending=False).plot(
    kind='bar',
    ylabel='Медиана показателя акций',
    title='Акционные покупки по категориям',
    rot=15,
    figsize=(10, 10)
);

# %% [markdown]
# Этот график показывает какие были медианные акции по отдельным группам товаров. Например, если бы на какую-то группу товаров были акции почти постоянно под 0.9, то это было довольно занятно и странно. Впрочем и без этого, мы можем наблюдать, что акции на "товары для детей" зачастую с более высокой скидкой. Возможно, такие скидки формируют дополнительный признак потенциальных покупателей по скидкам. Вполне возможно, что молодые мамы как раз ждут более высоких скидок и покупают товары, в отличие от покупки кухонной посуды.

# %%
segment_buyers[
    segment_buyers['разрешить_сообщать'] == 'да'
]['популярная_категория'].value_counts(normalize=True).plot(
    kind='bar',
    ylabel='доля',
    rot=15,
    figsize=(10, 10),
    alpha=0.5,
    color='r'
);
segment_buyers[
    segment_buyers['разрешить_сообщать'] == 'нет'
]['популярная_категория'].value_counts(normalize=True).plot(
    kind='bar',
    ylabel='доля',
    rot=15,
    title='Категории по статусу оповещения',
    figsize=(10, 10),
    alpha=0.5,
    color='y'
);
plt.legend(['Разрешил оповещать', 'Запретил оповещать']);

# %% [markdown]
# Пользователи чаще отказываются от оповещениям от тех категорий, по которым совершались акционные покупки чаще - "товары для детей" и "домашний текстиль". В дополнение к анализу сегмента - спонтанные покупки? Вижу скидку в этом магазине лучше, то сразу беру, в отличие от покупки мелкой бытовой техники, при которой дольше планируется эта покупка.

# %%
segment_buyers[
    segment_buyers['тип_сервиса'] == 'стандарт'
]['популярная_категория'].value_counts(normalize=True).plot(
    kind='bar',
    ylabel='доля',
    rot=15,
    figsize=(10, 10),
    alpha=0.5,
    color='r'
);
segment_buyers[
    segment_buyers['тип_сервиса'] == 'премиум'
]['популярная_категория'].value_counts(normalize=True).plot(
    kind='bar',
    ylabel='доля',
    rot=15,
    title='Категории товаров с учетом типа сервиса',
    figsize=(10, 10),
    alpha=0.5,
    color='y'
);
plt.legend(['стандарт', 'премиум']);

# %% [markdown]
# Так же получается, что товары для детей чаще покупают с премиумом, как и млекую бытовую технику, а вот косметику и аксесуары покупают 50/50 - как с периумом так и без.

# %% [markdown]
# **Вывод:** в дополнение по тем пользователям, которые берут товары зачастую по акциям, скорее всего это молодые родители, с премиум аккаунтом, судя по всему потому, что по товарам этой категории чаще проводятся акции и скидки и премиум позволяет купить такие товары по более привлекательной цене.

# %% [markdown]
# <a id="31"></a>
# ## Общий вывод

# %% [markdown]
# **Задача:** построить модель, которая предскажет вероятность снижения покупательской активности клиента в следующие три месяца. В исследование нужно включить дополнительные данные финансового департамента о прибыльности клиента: какой доход каждый покупатель приносил компании за последние три месяца. Используя данные модели и данные о прибыльности клиентов, нужно выделить сегменты покупателей и разработать для них персонализированные предложения.
#
# **Исходные данные и предобработка:** (вот я вообще не понял, зачем мы в вывод пихаем введение...) имеем 4 файла с разными данными об активностях пользоватлеей магазина выручке магазина. Рассмотрели все данные, проверили на дубликаты, на отсутсвие данных и объединили фреймы для построения модели.
#
# **Поиск лучшей модели:** ну...я дней 5 строил из себя DS мидла, чтобы понять как заставить SCV модель и shap работать вместе, но большую подсказку мне дал коллега и вроде бы уже получилось что-то адекватное. Мне понравилась теория, где мы взяли идельный момент с числами и построили shap на линейной модели. Милота, никаких сложностей, а потом в проекты мы получили модель SCV и встряли, потому что её использование это явно не наш уровень, и теории мало по ней, а гугл только усложняет процесс. При этом в теории нам пишут, мол, вот так вы можете кодировать признаки отдельно от пайплайнов - неть! Оно так не работает. Потом мы минут по 30 ждали GridSearchCV при поиске модели и исправлении ошибок, провалились с треском и ушли в Random, нагуглили что-то для решения, и с какой-то стати скормили модельке весь фрейм для предсказания - ах да, в теории тоже не было этого момента. А наставник в целом не может давать такие подсказки, потому что они были бы решением. Поиск был сложным, но оно работает. Я так же поразбирался с отдельными пайплайнами, потыкал, нашел более простой способ формирования заголовков...в общем, такое ощущение, что в этом пункте от меня ждут: "ля мы что придумали, а как ты справился?". Чтобы сделать проект нужно делать этот проект ранее или общаться с мидлом, что даст дополнительную теорию, что позволит выполнить проект. Или просто нужно переместится в будущее, а потом вернуться.
#
# **Лушая модель:** LogisticRegression(C=4, penalty='l1', random_state=4241,solver='liblinear')).
#
# **Вывод и предложения для сегмента:** у выбранного сегмента пользователей в 30% случаев примерно имеется премиум сервис, 3/4 всех пользователей согласились получать рассылки, в целом пользователей можно разделить на две группы по части покупок по акциям, наиболее популярные товары для покупок и приносящих прибыль - товары для детей, косметика и аксессуары, а так же домашний текстиль. выслать категории без подписки предложения о таковой, что может повысить нашу выручку с этого, а покупателем позволит покупать товары более выгодно и получать информацию об акциях и скидках раньше других пользователей; можно провести рекламную компанию на наиболее популярные категории в течение следующих нескольких месяцев, что может увеличить объем продаж, либо сосредоточиться на наименее популярных категоряих и рекламы товаров этой категории - ожидая, что это послужит напоминанием пользователем о покупках, которые они хотели сделать, но не сделали; если реализовано отслеживание определенных категорий товаров, то отдельно для пользователей, которые интересовались определенными категорями высылать отдельную рекламную рассылку по таким товарам

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# Круто, что видишь проблемы и самостоятельно их решаешь.
#
# По Shap я рекомендую такой подход и код (в целом идентичен твоему решению)
#     :
#
# ```
#
#
# X_train_2 = pipe_final.named_steps['preprocessor'].fit_transform(X_train)
#
# explainer = shap.Explainer(randomized_search.best_estimator_.named_steps['models'], X_train_2)
#
# X_test_2 = pipe_final.named_steps['preprocessor'].transform(X_test)
#
# feature_names = pipe_final.named_steps['preprocessor'].get_feature_names_out()
#
# X_test_2 = pd.DataFrame(X_test_2, columns=feature_names)
#
# shap_values = explainer(X_test_2)
#
# display(shap.plots.bar(shap_values, max_display=22))
# shap.plots.beeswarm(shap_values, max_display=22)
#
#
# ```
#
# Абсолютно верно уточняешь, что для простых моделей Shap работает из коробки без дополнительного шаманства.
#
#
# По идее, нам просто нужно подать в функцию shap.Explainer() модель и тренировочную выборку, а затем в функцию отрисовки графика shap.plots.bar() эксплейнер с тестовой выборкой explainer(X_test_2).
#
# Однако так как мы используем пайпланый, важно подавать в эксклейнер тренировочную выборку после масштабирования и кодирования Поэтому мы берем из пайплайна только соответствующие шаги и применяем к тренировочной выборке.
#
# `X_train_2 = pipe_final.named_steps['preprocessor'].fit_transform(X_train)`
#
# То же самое делаем с тестовой выборкой.
#
# `X_test_2 = pipe_final.named_steps['preprocessor'].transform(X_test)`
#
# И отдельным шагом сохраняем список с названиями столбцов:
#
# `feature_names = pipe_final.named_steps['preprocessor'].get_feature_names_out()`
#
# После чего получаем датасет с колонками после масштабирования и экнодинга и их названиями.
#
# `X_test_2 = pd.DataFrame(X_test_2, columns=feature_names)`
#
# Дальше оставется все это использовать:
#
# ```
# shap_values = explainer(X_test_2)
#
# display(shap.plots.bar(shap_values, max_display=22))
#
# ```
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# #### 📖 **Полезные ссылки**
#
# * [Подробное описание метрики ROC AUC](https://alexanderdyakonov.wordpress.com/2017/07/28/auc-roc-площадь-под-кривой-ошибок/)
#
# #### Книги
# * [Учебник по машинному обучению | Школа анализа данных](https://academy.yandex.ru/handbook/ml)
#
# #### Материалы
# * [Feature selection | Scikit-learn Documentation](https://scikit-learn.org/stable/modules/feature_selection.html)
# * [Y. Gavrilova. Classification Algorithms: A Tomato-Inspired Overview | Serokell](https://serokell.io/blog/classification-algorithms)
#
# </div>
